# %%
import cv2
import socket
import urllib
import pickle
import numpy as np


url = 'http://192.168.43.245:8080/shot.jpg'

s = socket.socket(socket.AF_INET,socket.SOCK_STREAM)
server_ip="192.168.43.204"
server_port=2222

s.connect((server_ip,server_port))

while True:
    
    received_data = s.recv(1000000)
    print("Recieving")
    
    imgResp=urllib.request.urlopen(url)
    imgNp=np.array(bytearray(imgResp.read()),dtype=np.uint8)
    img=cv2.imdecode(imgNp,-1)
    img = cv2.resize(img,(700,500))
    ret, buffer = cv2.imencode('.jpg',img)
    Image_in_bytes = pickle.dumps(buffer)
    
    s.send(Image_in_bytes)
    try:
        data = pickle.loads(received_data)
        data = cv2.imdecode(data,cv2.IMREAD_COLOR)
        if data is not None :
            cv2.imshow('CLIENT',data)
            if cv2.waitKey(10) == 13 :
                break
    except: 
        print("Waiting for the server!")
     
cv2.destroyAllWindows()
# Out:
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# Recieving
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-1-d4fe39b38ab9> in <module>
#      21     imgResp=urllib.request.urlopen(url)
#      22     imgNp=np.array(bytearray(imgResp.read()),dtype=np.uint8)
# ---> 23     img=cv2.imdecode(imgNp,-1)
#      24     img = cv2.resize(img,(700,500))
#      25     ret, buffer = cv2.imencode('.jpg',img)
#
# error: OpenCV(4.4.0) C:\Users\appveyor\AppData\Local\Temp\1\pip-req-build-h4wtvo23\opencv\modules\imgcodecs\src\loadsave.cpp:753: error: (-215:Assertion failed) !buf.empty() in function 'cv::imdecode_'
